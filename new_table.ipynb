# %%
import pandas as pd

# %%
df = pd.read_csv("metadata_almost_clean.csv")

# %%
new_dataframe = df['PMID'], df['FAU'], df['TI'], df['AB'], df['IS'], df['DP'], df['AUID'], df['AID'], df['LA'], df['PL'], df['OT'], df['CI'], df['RN'], df['MH']

# %%
df_T = pd.DataFrame(new_dataframe)

# %%
df_t = df_T.T

# %%
df_t
# Out:
#           PMID                                                FAU  \
# 0     24501647  ['Anderson, Iain', 'Teshima, Huzuki', 'Nolan, ...
# 1     33903107             ['Kornelsen, Vanessa', 'Kumar, Ayush']
# 2     33901665  ['Matuschek, Erika', 'Brolund, Alma', 'Lindsjo...
# 3     33892804  ['Ngoi, Soo Tein', 'Chong, Chun Wie', 'Ponnamp...
# 4     33889142  ['Vega, Fernando E', 'Emche, Sarah', 'Shao, Jo...
# ...        ...                                                ...
# 1526  33735544  ['Gomez Rufo, D', 'Garcia Sanchez, E', 'Garcia...
# 1527  33652790  ['Doroftei, Bogdan', 'Ilie, Ovidiu-Dumitru', '...
# 1528  33640187  ['de Souza, Lucilene Sales', 'Sardinha, Jose C...
# 1529  33593837                                   ['Dumke, Roger']
# 1530  33553066  ['Cheah, Fook-Choe', 'Lai, Chee Hoe', 'Tan, Ge...
#
#                                                      TI  \
# 0     Genome sequence of Frateuria aurantia type str...
# 1     Multidrug Resistance Efflux Pumps in Acinetoba...
# ...

# %%
df_t.to_csv("final_dataframe.csv")
